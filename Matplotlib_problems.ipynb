# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x=[1,2,3,4,5,6,7]
y=[49,48,51,52,50,47,54]
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[49,48,51,52,50,47,54]
plt.xlabel("days")
plt.ylabel("temperature")
plt.title("whether")
plt.plot(x,y,color="green",linewidth=5,linestyle="dotted")

# %%
company=["Googl","Amzn","MSFT","FB"]
revenue=[90,136,89,27]
profit=[30,12,40,5]

# %%
plt.bar(company,revenue,label="revenue")
plt.bar(company,profit,label="Profit")
plt.legend()

# %%
plt.bar(company,revenue,label="revenue",width=.5)

plt.bar(company,profit,label="Profit",width=.5)
plt.xlabel("company")

plt.legend()

# %%
# plotting histogram
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar)
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar,bins=3)
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar,bins=3,rwidth=0.95)
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95)
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,color="g")
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,histtype="step")
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  [<matplotlib.patches.Polygon at 0x20ddf6e0280>])

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,color="g")
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]


plt.hist([blood_sugar_women,blood_sugar_men],rwidth=0.95,bins=[80,100,125,150],color=["green",'yellow'],
        label=["men","women"])
plt.legend()

# %%
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]


plt.hist([blood_sugar_women,blood_sugar_men],rwidth=0.95,bins=[80,100,125,150],color=["green",'yellow'],
        label=["men","women"])
plt.xlabel("sugar level")
plt.ylabel("Number of Patients")
plt.title("Blood sugar analysis")
plt.legend()
